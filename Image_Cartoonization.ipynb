# %% [markdown]
# <a href="https://colab.research.google.com/github/priyalagarwal27/Image-Cartoonization/blob/main/Image_Cartoonization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing libraries
import cv2
import numpy as np

# %%
#Reading Image
img= cv2.imread("eleven.jpg")

# %%
#Edges
gray= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray= cv2.medianBlur(gray,5)
edges= cv2.adaptiveThreshold(gray,255,
       cv2.ADAPTIVE_THRESH_MEAN_C,
       cv2.THRESH_BINARY,9,9)

# %%
#Cartoonization
color = cv2.bilateralFilter(img, 9,250,250)
cartoon = cv2.bitwise_and(color, color, mask=edges)

from google.colab.patches import cv2_imshow
cv2_imshow(img)
cv2_imshow(edges)
cv2_imshow(cartoon)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F3BD503B890>
# <PIL.Image.Image image mode=L size=300x300 at 0x7F3BD503BB50>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F3BD503B390>
